# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv(r"D:\PROJECTS\SWIGGY_RESTAURANT_RECOMMENDATION_SYSTEM\DATA\swiggy_raw.csv")

# %%
df.head()
# Out:
#        id               name    city rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
# 2  158203  theka coffee desi  Abohar    3.8     100+ ratings  ₹ 100
# 3  187912          Singh Hut  Abohar    3.7      20+ ratings  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     --  Too Few Ratings  ₹ 250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# 4  https://www.swiggy.com/restaurants/grill-maste...
#
#                                              address              menu
# 0  AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...  Menu/567335.json
# 1  Janta Sweet House, Bazar No.9, Circullar Road,...  Menu/531342.json
# 2         theka coffee desi, sahtiya sadan road city  Menu/158203.json
# 3    Singh Hut, CIRCULAR ROAD NEAR NEHRU PARK ABOHAR  Menu/187912.json
# 4  GRILL MASTERS, ADA Heights, Abohar - Hanumanga...  Menu/543530.json

# %%
df.shape
# Out:
# (148541, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148541 entries, 0 to 148540
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148541 non-null  int64
#  1   name          148455 non-null  object
#  2   city          148541 non-null  object
#  3   rating        148455 non-null  object
#  4   rating_count  148455 non-null  object
#  5   cost          148410 non-null  object
#  6   cuisine       148442 non-null  object
#  7   lic_no        148312 non-null  object
#  8   link          148541 non-null  object
#  9   address       148455 non-null  object
#  10  menu          148541 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 12.5+ MB

# %%
df.describe()
# Out:
#                   id
# count  148541.000000
# mean   363466.378912
# std    167890.977174
# min       211.000000
# 25%    233320.000000
# 50%    412628.000000
# 75%    502223.000000
# max    581031.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# id                0
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# lic_no          229
# link              0
# address          86
# menu              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'name', 'city', 'rating', 'rating_count', 'cost', 'cuisine',
#        'lic_no', 'link', 'address', 'menu'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148255 entries, 0 to 148540
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148255 non-null  int64
#  1   name          148255 non-null  object
#  2   city          148255 non-null  object
#  3   rating        148255 non-null  object
#  4   rating_count  148255 non-null  object
#  5   cost          148255 non-null  object
#  6   cuisine       148255 non-null  object
#  7   lic_no        148255 non-null  object
#  8   link          148255 non-null  object
#  9   address       148255 non-null  object
#  10  menu          148255 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 13.6+ MB

# %%
df['rating'] = df['rating'].replace('--', np.nan)
df['rating'] = df['rating'].astype(float)

# %%
def clean_rating_count(x):
    if pd.isna(x):
        return 0
    
    x = str(x).strip()
    x = x.replace("+ ratings", "")
    x = x.replace("+", "")
    x = x.replace("Too Few Ratings", "0")
    x = x.replace(",", "")
    
    if "K" in x:
        return float(x.replace("K", "")) * 1000
    
    try:
        return float(x)
    except:
        return 0

df["rating_count"] = df["rating_count"].apply(clean_rating_count)

# %%
df['cost'] = df['cost'].str.replace('₹', '', regex=False).astype(float)
df['cost'].fillna(df['cost'].median(), inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18220\3751217482.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cost'].fillna(df['cost'].median(), inplace=True)

# %%
df['rating'].fillna(df['rating'].mean(), inplace=True)
df['city'] = df['city'].str.split(',').str[-1]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18220\538131218.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(df['rating'].mean(), inplace=True)

# %%
df['cuisine'] = (df['cuisine'].str.lower().str.split(',').str[0].str.strip())

# %%
df['cuisine'].unique()
# Out:
# array(['beverages', 'sweets', 'fast food', 'italian-american',
#        'continental', 'north indian', 'snacks', 'indian', 'juices',
#        'tandoor', 'punjabi', 'mughlai', 'pizzas', 'chinese', 'ice cream',
#        'chaat', 'bakery', 'american', 'european', 'biryani',
#        'south indian', 'desserts', 'street food', 'nepalese', 'paan',
#        'healthy food', 'bengali', 'thalis', 'waffle', 'arabian', 'combo',
#        'tibetan', 'burgers', 'bihari', 'italian', 'salads', 'kebabs',
#        'asian', 'thai', 'north eastern', 'cafe', 'pan-asian', 'lebanese',
#        'maharashtrian', 'mexican', 'pastas', 'rajasthani', 'gujarati',
#        'seafood', 'japanese', 'sushi', 'middle eastern', 'french',
#        'hyderabadi', 'grill', 'svanidhi street food vendor', 'afghani',
#        'oriental', 'home food', 'barbecue', 'korean', 'kerala', 'andhra',
#        'british', 'oriya', 'portuguese', 'lucknowi', 'mangalorean',
#        'chettinad', 'mediterranean', 'naga', 'turkish', 'assamese',
#        'steakhouse', 'coastal', 'tex-mex', 'vietnamese', 'awadhi',
#        'spanish', 'ice cream cakes', 'kashmiri', 'german', 'singaporean',
#        'burmese', 'jain', 'persian', 'indonesian', 'parsi', 'goan',
#        'african', 'bangladeshi', 'greek', 'sindhi', 'default',
#        '8:15 to 11:30 pm', 'malaysian', 'bakery products',
#        'south american', 'keto', 'free delivery ! limited stocks!',
#        'haleem', 'malwani', 'telangana', 'bhutanese', 'rayalaseema',
#        'tribal', 'konkan', 'sri lankan',
#        'discount offer from garden cafe express kankurgachi',
#        'special discount from (hotel swagath)', 'khasi',
#        'popular brand store', 'grocery products'], dtype=object)

# %%
df = df[~df['cuisine'].str.contains(
    'discount|offer|delivery|pm|am|grocery',
    case=False,
    na=False
)]

# %%
df
# Out:
#             id                      name      city    rating  rating_count  \
# 0       567335            AB FOODS POINT    Abohar  3.894513           0.0
# 1       531342         Janta Sweet House    Abohar  4.400000          50.0
# 2       158203         theka coffee desi    Abohar  3.800000         100.0
# 3       187912                 Singh Hut    Abohar  3.700000          20.0
# 5       158204                 Sam Uncle    Abohar  3.600000          20.0
# ...        ...                       ...       ...       ...           ...
# 148536  553122          The Food Delight  Yavatmal  3.894513           0.0
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal  3.894513           0.0
# 148538  559435           Cafe Bella Ciao  Yavatmal  3.894513           0.0
# 148539  418989               GRILL ZILLA  Yavatmal  3.894513           0.0
# 148540  447770            Lazeez kitchen  Yavatmal  3.894513           0.0
#
#          cost      cuisine          lic_no  \
# 0       200.0    beverages  22122652000138
# 1       200.0       sweets  12117201000112
# 2       100.0    beverages  22121652000190
# 3       250.0    fast food  22119652000167
# 5       200.0  continental  22119652000052
# ...       ...          ...             ...
# 148536  200.0    fast food  21522053000452
# 148537  300.0       pizzas         license
# 148538  300.0    fast food  21522251000378
# 148539  250.0  continental  21521251000241
# 148540  200.0       pizzas  21521251000634
#
#                                                      link  \
# 0       https://www.swiggy.com/restaurants/ab-foods-po...
# 1       https://www.swiggy.com/restaurants/janta-sweet...
# 2       https://www.swiggy.com/restaurants/theka-coffe...
# 3       https://www.swiggy.com/restaurants/singh-hut-n...
# 5       https://www.swiggy.com/restaurants/sam-uncle-c...
# ...                                                   ...
# 148536  https://www.swiggy.com/restaurants/the-food-de...
# 148537  https://www.swiggy.com/restaurants/maitri-food...
# 148538  https://www.swiggy.com/restaurants/cafe-bella-...
# 148539  https://www.swiggy.com/restaurants/grill-zilla...
# 148540  https://www.swiggy.com/restaurants/lazeez-kitc...
#
#                                                   address              menu
# 0       AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...  Menu/567335.json
# 1       Janta Sweet House, Bazar No.9, Circullar Road,...  Menu/531342.json
# 2              theka coffee desi, sahtiya sadan road city  Menu/158203.json
# 3         Singh Hut, CIRCULAR ROAD NEAR NEHRU PARK ABOHAR  Menu/187912.json
# 5       Sam Uncle, hanumangarh road near raja bajaj sh...  Menu/158204.json
# ...                                                   ...               ...
# 148536  The Food Delight, 94MC+X35, New Singhania Naga...  Menu/553122.json
# 148537  MAITRI FOODS & BEVERAGES, POLIC MITRYA SOCIETY...  Menu/562647.json
# 148538  Cafe Bella Ciao, SHOP NO 2 NEMANI MARKET SBI S...  Menu/559435.json
# 148539  GRILL ZILLA, SHO NO 2/6, POSTEL GROUND CHOWPAT...  Menu/418989.json
# 148540  Lazeez kitchen, 94G3+2RR, Wadgaon, Yavatmal, M...  Menu/447770.json
#
# [141739 rows x 11 columns]

# %%
df_cleaned = df[['name','city','rating','rating_count','cost','cuisine']]

# %%
df_cleaned.reset_index(drop=True, inplace=True)

# %%
df_cleaned.to_csv(r"D:\PROJECTS\SWIGGY_RESTAURANT_RECOMMENDATION_SYSTEM\DATA\cleaned_data.csv", index=False)

# %%
len(df_cleaned)
# Out:
# 141739

# %%
categorical_cols = ['city','cuisine']
numerical_cols = ['rating','rating_count','cost']

# %%
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

encoded_cat = encoder.fit_transform(df_cleaned[categorical_cols])

# %%
encoded_cat_df = pd.DataFrame(
    encoded_cat,
    columns=encoder.get_feature_names_out(['city','cuisine'])
)


encoded_df = pd.concat(
    [df[numerical_cols].reset_index(drop=True), encoded_cat_df],
    axis=1
)

# %%
encoded_df = encoded_df.fillna(0)

# %%
encoded_df.to_csv(r"D:\PROJECTS\SWIGGY_RESTAURANT_RECOMMENDATION_SYSTEM\DATA\encoded_data.csv", index=False)

# %%
with open("D:\PROJECTS\SWIGGY_RESTAURANT_RECOMMENDATION_SYSTEM\DATA\encoder.pkl", "wb") as f:
    pickle.dump(encoder, f)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\HP\AppData\Local\Temp\ipykernel_18220\3468453773.py:1: SyntaxWarning: invalid escape sequence '\P'
#   with open("D:\PROJECTS\SWIGGY_RESTAURANT_RECOMMENDATION_SYSTEM\DATA\encoder.pkl", "wb") as f:

# %%
scaler = StandardScaler()

scaled_data = scaler.fit_transform(encoded_df)

scaled_df = pd.DataFrame(scaled_data,columns=encoded_df.columns,index=df.index)

# %%
scaled_df.to_csv(r"D:\PROJECTS\SWIGGY_RESTAURANT_RECOMMENDATION_SYSTEM\DATA\scaled_data.csv", index=False)

# %%
with open(r"D:\PROJECTS\SWIGGY_RESTAURANT_RECOMMENDATION_SYSTEM\DATA\scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)
